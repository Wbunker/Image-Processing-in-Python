# %% [markdown]
# # Different ways to represent images make different manipulations easier
#
# ## RGB
#
# Has red, green, blue pixels values in 3 different arrays
#
#
# ## CEILAB
#
# Has luminance, red-green, blue-yellow values in 3 different arrays
#
# So it is easier to remove color and change brightness in this representation

# %%
import numpy as np
from skimage.io import imread
from skimage.color import rgb2lab, lab2rgb
import matplotlib.pylab as plt

im = imread('data/tropical-humming-bird.jpg')

# %%
# set the red-green and blue-yellow values to zero to remove the color

# transform to ceilab format
im1 = rgb2lab(im)

im1[:,:,1] = im1[:,:,2] = 0
im1 = lab2rgb(im1)

# %%
plt.figure(figsize=(20,10))
plt.subplot(121), plt.imshow(im), plt.axis('off'), plt.title('Original image', size=20)
plt.subplot(122), plt.imshow(im1), plt.axis('off'), plt.title('Grey scale image', size=20)
plt.show()

# %%
# here we are increasing and decreasing the luminance values in the first array

im1 = rgb2lab(im)
im1[:,:,0] = im1[:,:,0] + 20
im1 = lab2rgb(im1)

im2 = rgb2lab(im)
im2[:,:,0] = im2[:,:,0] - 20
im2 = lab2rgb(im2)

plt.figure(figsize=(20,10))
plt.subplot(131), plt.imshow(im), plt.axis('off'), plt.title('Original image', size=20)

plt.subplot(132), plt.imshow(im1), plt.axis('off'), plt.title('Brighter image', size=20)
plt.subplot(133), plt.imshow(im2), plt.axis('off'), plt.title('Darker image', size=20)


plt.show()
# Out:
# /home/bunker/anaconda3/lib/python3.9/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1428 pixels
#   return func(*args, **kwargs)
